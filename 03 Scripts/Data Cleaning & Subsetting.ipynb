# %% [markdown]
# Importing and File Location

# %%
#import libraries
import pandas as pd
import numpy as np
import os

#creating Paths
path= r'C:\Users\wjzak\Dropbox\Career Foundry\Data Immersion\Module 4- Python Fundamentals for Data Analysts\07-2025 Instacart Basket Analysis'

#using the path to pull file name and read orders.csv
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)
#using the path to pull file name and read products.csv
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %% [markdown]
# Coding and Solutions

# %%
#dropping column eval_set from data
df_ords.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
#change the dataframe for the future with the following command and including title
df_ords_2 = df_ords.drop(columns = ['eval_set'])

# %%
#shows missing values in Days since prior order column
df_ords['days_since_prior_order'].value_counts(dropna = False)
# Out:
# days_since_prior_order
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: count, dtype: int64

# %%
#rename a column from dow to day of week
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
#Changes the type of data to a string so the describe() command doesnt report it in descriptives
df_ords['order_id'] = df_ords['order_id'].astype('str')
#returns data type of new order_id column
#plural uses dtypes with an s
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %%
#creating Paths
path= r'C:\Users\wjzak\Dropbox\Career Foundry\Data Immersion\Module 4- Python Fundamentals for Data Analysts\07-2025 Instacart Basket Analysis'

#using the path to pull file name and read departments
df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
#transpose data on table using T.
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#creates a new dataframe that is transposed
df_dep_t = df_dep.T
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#adds an index to the dataframe
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
#take the first row of df_dep_t for the header
new_header = df_dep_t.iloc[0]
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
#copies all the data from the first row on that is what [1:] means
df_dep_t_new = df_dep_t[1:]
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
df_dep_t_new.columns = new_header #set the headr row as the df header
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# Create Data Dictionary

# %%
data_dict = df_dep_t_new.to_dict('index')
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %%
#snacks dataframe is using department id 19 and indexes it
df_snacks =  df_prods[df_prods['department_id']==19]
#other ways to obtain the same thing as above.
df_snacks_2 = df_prods.loc[df_prods['department_id'] == 19]
#the isin command can have multiple values so it can include several here
df_snacks_3 = df_prods.loc[df_prods['department_id'].isin([19])]
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
#breakdown of the code above step by step
df_prods['department_id']==19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %% [markdown]
# Exporting Data

# %%
#exports data to orders_wrangled- changes folder to prepared data
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %% [markdown]
# **TASK 4.4- Coding/Data Wrangling**

# %%
#import libraries
import pandas as pd
import numpy as np
import os

#creating Paths
path= r'C:\Users\wjzak\Dropbox\Career Foundry\Data Immersion\Module 4- Python Fundamentals for Data Analysts\07-2025 Instacart Basket Analysis'

#using the path to pull file name and read orders.csv
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)
#using the path to pull file name and read products.csv
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)
#using the path to pull file name and read departments
df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %%
#identify another column that needs to be corrected
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
#change user_id to a string variable as they are unique identifiers
df_ords['user_id'] = df_ords['user_id'].astype('str')
df_ords['user_id'].dtype

#the user is not intuitive to the nature of the data. This is a customer identifer
df_ords.rename(columns = {'user_id' : 'customer_id'}, inplace = True)

# %%
df_ords.describe()
# Out:
#            order_id  order_number     order_dow  order_hour_of_day  \
# count  3.421083e+06  3.421083e+06  3.421083e+06       3.421083e+06
# mean   1.710542e+06  1.715486e+01  2.776219e+00       1.345202e+01
# std    9.875817e+05  1.773316e+01  2.046829e+00       4.226088e+00
# min    1.000000e+00  1.000000e+00  0.000000e+00       0.000000e+00
# 25%    8.552715e+05  5.000000e+00  1.000000e+00       1.000000e+01
# 50%    1.710542e+06  1.100000e+01  3.000000e+00       1.300000e+01
# 75%    2.565812e+06  2.300000e+01  5.000000e+00       1.600000e+01
# max    3.421083e+06  1.000000e+02  6.000000e+00       2.300000e+01
#
#        days_since_prior_order
# count            3.214874e+06
# mean             1.111484e+01
# std              9.206737e+00
# min              0.000000e+00
# 25%              4.000000e+00
# 50%              7.000000e+00
# 75%              1.500000e+01
# max              3.000000e+01

# %%
#most common time of the day to place an order is 10am
df_ords['order_hour_of_day'].mode()
# Out:
# 0    10
# Name: order_hour_of_day, dtype: int64

# %%
#creates hour that = column order hour of the day
hour = df_ords['order_hour_of_day']
#creates mode_value to lock in the mode value
mode_value = hour.mode().iloc[0]
#uses the above to variables to count the instaces of the mode value
mode_count = hour.value_counts()[mode_value]
mode_count #report the frequency for the mode value of 10 (or 10:00am)

#4) The most common hour to order Instacart is 10:00a. This occurred 288,418 times in these data.
# Out:
# np.int64(288418)

# %% [markdown]
# Data Dictionary Breakdown- Produce and Dinner Party

# %%
#add a data dictionary and report the 4th department of produce
data_dict = df_dep_t_new.to_dict('index')
data_dict 
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
#show what is indexed for id 14 or breakfast
df_prods[df_prods['department_id']==14]
#set data frame for produce
df_breakfast = df_prods[df_prods['department_id']==14]
df_breakfast
#This subset of information is only breakfast data.
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %%
#This pulls only data from the alcohol, deli, beverages, and meta/seafood departments
df_dinner_party = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]
df_dinner_party
#8) This dinner party dataframe has 7,650 rows of data
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %% [markdown]
# USER 1 Information

# %%
#had to change this a little to match what was adjusted above and make this a string.
df_user1 = df_ords[df_ords['customer_id'] == '1']
df_user1
#this shows all the info for user_id 1
#10) This customer has ordered 11 times in the past month. They mostly placed orders between Monday - Thursday.
#The customer did not place any orders on Friday or the weekend. They offten placed orders in the morning but on occasion
#they place them in the evening.
# Out:
#     order_id customer_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329           1    prior             1          2                  8
# 1    2398795           1    prior             2          3                  7
# 2     473747           1    prior             3          3                 12
# 3    2254736           1    prior             4          4                  7
# 4     431534           1    prior             5          4                 15
# 5    3367565           1    prior             6          2                  7
# 6     550135           1    prior             7          1                  9
# 7    3108588           1    prior             8          1                 14
# 8    2295261           1    prior             9          1                 16
# 9    2550362           1    prior            10          4                  8
# 10   1187899           1    train            11          4                  8
#
#     days_since_prior_order
# ...

# %%
#additional summary stats for the user 1
df_user1.describe()
# Out:
#            order_id  order_number  order_dow  order_hour_of_day  \
# count  1.100000e+01     11.000000  11.000000          11.000000
# mean   1.923450e+06      6.000000   2.636364          10.090909
# std    1.071950e+06      3.316625   1.286291           3.477198
# min    4.315340e+05      1.000000   1.000000           7.000000
# 25%    8.690170e+05      3.500000   1.500000           7.500000
# 50%    2.295261e+06      6.000000   3.000000           8.000000
# 75%    2.544846e+06      8.500000   4.000000          13.000000
# max    3.367565e+06     11.000000   4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %% [markdown]
# Exporting Data to Prepared Data

# %%
#exports data to orders_wrangled- changes folder to prepared data
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

#exports data to departments_wrangled- changes folder to prepared data
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))
